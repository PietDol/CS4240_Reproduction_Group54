# %%
# Needed to install the packages from requirements.txt that aren't already available in Kaggle
# !pip install pytorch_msssim==0.2.1; pip install dahuffman==0.4.1; pip install Pillow; pip install yaspin==2.1.0;

# %%
import nervfile_2

# %%
import sys
sys.path.append('/kaggle/input/gitproject')

# %% [markdown]
# Information about different learning rates:
#
# The model is trained with the following learning rates and they output:
# 1. 0.01: Eval best_PSNR at epoch300:	720p: current: 12.20	best: 25.75 	best_msssim: 0.8687
# 2. 0.0075:
# 3. 0.005: Eval best_PSNR at epoch300:	720p: current: 33.08	best: 33.08 	best_msssim: 0.9688
# 4. 0.0025:
# 5. 0.001: Eval best_PSNR at epoch300:	720p: current: 32.88	best: 32.88 	best_msssim: 0.9676
# 6. 0.00075:
# 7. 0.0005 (used by authors): Eval best_PSNR at epoch300:	720p: current: 32.13	best: 32.13 	best_msssim: 0.9591
# 8. 0.0001: Eval best_PSNR at epoch300:	720p: current: 27.71	best: 27.71 	best_msssim: 0.8814

# %% [markdown]
# Information about different learning rates (1200 epochs):
#
# The model is trained with the following learning rates and they output:
# 1. 0.01: Eval best_PSNR at epoch1200:	720p: current: 12.20	best: 27.31 	best_msssim: 0.9135
# 2. 0.005: Eval best_PSNR at epoch1200:	720p: current: 31.94	best: 31.94 	best_msssim: 0.9258
# 3. 0.003: Eval best_PSNR at epoch1200:	720p: current: 33.89	best: 33.89 	best_msssim: 0.9737
# 4. 0.001: Eval best_PSNR at epoch1200:	720p: current: 33.94	best: 33.94 	best_msssim: 0.9738
# 5. 0.00075: Eval best_PSNR at epoch1200:	720p: current: 33.97	best: 33.97 	best_msssim: 0.9738
# 6. 0.0005: Eval best_PSNR at epoch1200:	720p: current: 34.01	best: 34.01 	best_msssim: 0.9735
# 7. 0.00025: Eval best_PSNR at epoch1200:	720p: current: 33.56	best: 33.56 	best_msssim: 0.9697
# 8. 0.0001: Eval best_PSNR at epoch1200:	720p: current: 31.54	best: 31.54 	best_msssim: 0.9481

# %%
# lr 0.01 1200 epochs
# !python '/kaggle/usr/lib/nervfile_2/nervfile_2.py' -e 1200   --lower-width 96 --num-blocks 1 --dataset data/bunny --frame_gap 1 \
    --outf bunny_ab --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  \
    --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv \
    -b 1  --lr 0.01 --norm none --act swish

# %%
# lr 0.005 1200 epochs
# !python '/kaggle/usr/lib/nervfile_2/nervfile_2.py' -e 1200   --lower-width 96 --num-blocks 1 --dataset data/bunny --frame_gap 1 \
#     --outf bunny_ab --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  \
#     --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv \
#     -b 1  --lr 0.005 --norm none --act swish

# %%
# lr 0.003 1200 epochs
# !python '/kaggle/usr/lib/nervfile_2/nervfile_2.py' -e 1200   --lower-width 96 --num-blocks 1 --dataset data/bunny --frame_gap 1 \
    --outf bunny_ab --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  \
    --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv \
    -b 1  --lr 0.003 --norm none --act swish

# %%
# lr 0.001 1200 epochs
# !python '/kaggle/usr/lib/nervfile_2/nervfile_2.py' -e 1200   --lower-width 96 --num-blocks 1 --dataset data/bunny --frame_gap 1 \
#     --outf bunny_ab --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  \
#     --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv \
#     -b 1  --lr 0.001 --norm none --act swish

# %%
# lr 0.00075 1200 epochs
# !python '/kaggle/usr/lib/nervfile_2/nervfile_2.py' -e 1200   --lower-width 96 --num-blocks 1 --dataset data/bunny --frame_gap 1 \
#     --outf bunny_ab --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  \
#     --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv \
#     -b 1  --lr 0.00075 --norm none --act swish

# %%
# lr 0.0005 1200 epochs
# !python '/kaggle/usr/lib/nervfile_2/nervfile_2.py' -e 1200   --lower-width 96 --num-blocks 1 --dataset data/bunny --frame_gap 1 \
#     --outf bunny_ab --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  \
#     --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv \
#     -b 1  --lr 0.0005 --norm none --act swish

# %%
# lr 0.00025 1200 epochs
# !python '/kaggle/usr/lib/nervfile_2/nervfile_2.py' -e 1200   --lower-width 96 --num-blocks 1 --dataset data/bunny --frame_gap 1 \
#     --outf bunny_ab --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  \
#     --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv \
#     -b 1  --lr 0.00025 --norm none --act swish

# %%
# lr 0.0001 1200 epochs
# !python '/kaggle/usr/lib/nervfile_2/nervfile_2.py' -e 1200   --lower-width 96 --num-blocks 1 --dataset data/bunny --frame_gap 1 \
#     --outf bunny_ab --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  \
#     --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv \
#     -b 1  --lr 0.0001 --norm none --act swish

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir /kaggle/working/output/bunny_ab/data/bunny/embed1.25_40_512_1_fc_9_16_26__exp1.0_reduce2_low96_blk1_cycle1_gap1_e300_warm60_b1_conv_lr0.0005_cosine_Fusion6_Strd5,2,2,2,2_SinRes_actswish_/param_3.201905M/tensorboard/

# %%
# old versions for which the output is not saved
# !python '/kaggle/usr/lib/nervfile_2/nervfile_2.py' -e 300   --lower-width 96 --num-blocks 1 --dataset data/bunny --frame_gap 1 \
#     --outf bunny_ab --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  \
#     --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv \
#     -b 1  --lr 0.001 --norm none --act swish

# %%
# old versions for which the output is not saved
# !python '/kaggle/usr/lib/nervfile_2/nervfile_2.py' -e 300   --lower-width 96 --num-blocks 1 --dataset data/bunny --frame_gap 1 \
#     --outf bunny_ab --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  \
#     --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv \
#     -b 1  --lr 0.0001 --norm none --act swish

# %%
# old versions for which the output is not saved
# !python '/kaggle/usr/lib/nervfile_2/nervfile_2.py' -e 300   --lower-width 96 --num-blocks 1 --dataset data/bunny --frame_gap 1 \
#     --outf bunny_ab --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  \
#     --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv \
#     -b 1  --lr 0.005 --norm none --act swish

# %%
# new version
# !python '/kaggle/usr/lib/nervfile_2/nervfile_2.py' -e 300   --lower-width 96 --num-blocks 1 --dataset data/bunny --frame_gap 1 \
#     --outf bunny_ab --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  \
#     --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv \
#     -b 1  --lr 0.0025 --norm none --act swish

# %%
# new version
# !python '/kaggle/usr/lib/nervfile_2/nervfile_2.py' -e 300   --lower-width 96 --num-blocks 1 --dataset data/bunny --frame_gap 1 \
#     --outf bunny_ab --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  \
#     --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv \
#     -b 1  --lr 0.00075 --norm none --act swish

# %%
# new version
# !python '/kaggle/usr/lib/nervfile_2/nervfile_2.py' -e 300   --lower-width 96 --num-blocks 1 --dataset data/bunny --frame_gap 1 \
#     --outf bunny_ab --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  \
#     --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv \
#     -b 1  --lr 0.0075 --norm none --act swish
