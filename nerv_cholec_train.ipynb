# %%
# Needed to install the packages from requirements.txt that aren't already available in Kaggle
# !pip install pytorch_msssim==0.2.1; pip install dahuffman==0.4.1; pip install Pillow; pip install yaspin==2.1.0;
# Out:
# ...
# done
# ...
# done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4832 sha256=d47e80ca1ac4ab77dcd4840b0f2422e9ffa5d054c2bd465c6d97e67737208bc7
#   Stored in directory: /root/.cache/pip/wheels/a1/49/46/1b13a65d8da11238af9616b00fdde6d45b0f95d9291bac8452
# Successfully built termcolor
# ...
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.4.0
#     Uninstalling termcolor-2.4.0:
#       Successfully uninstalled termcolor-2.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.0.5 which is incompatible.
# ...

# %%
import nervfile
# Out:
# 2024-04-02 10:56:53.453752: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-02 10:56:53.453850: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-02 10:56:53.601562: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import sys
sys.path.append('/kaggle/input/gitproject')

# %% [markdown]
# Running video_50 on the small model:

# %%
# !python '/kaggle/usr/lib/model_nerv/nervfile.py' -e 1200   --lower-width 96 --num-blocks 1 --dataset video50_frames --frame_gap 1 \
    --outf video_50out --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  \
    --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv \
    -b 1  --lr 0.0005 --norm none --act swish
# Out:
# 2024-04-02 10:57:07.212432: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-02 10:57:07.212489: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-02 10:57:07.213904: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# Running video_70 on the small model:

# %%
# !python '/kaggle/usr/lib/model_nerv/nervfile.py' -e 1200   --lower-width 96 --num-blocks 1 --dataset video70_frames --frame_gap 1 \
    --outf video70out --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  \
    --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv \
    -b 1  --lr 0.0005 --norm none --act swish
# Out:
# 2024-04-02 15:09:32.110673: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-02 15:09:32.110741: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-02 15:09:32.112222: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
